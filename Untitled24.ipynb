# %% [markdown]
# # Retrieve raw by index label with loc()

# %%
import pandas as pd

# %%
bond=pd.read_csv("jamesbond.csv",index_col="Film")

# %%
bond.head()
# Out:
#                        Year         Actor       Director  Box Office  Budget  \
# Film
# Dr. No                 1962  Sean Connery  Terence Young       448.8     7.0
# From Russia with Love  1963  Sean Connery  Terence Young       543.8    12.6
# Goldfinger             1964  Sean Connery   Guy Hamilton       820.4    18.6
# Thunderball            1965  Sean Connery  Terence Young       848.1    41.9
# Casino Royale          1967   David Niven     Ken Hughes       315.0    85.0
#
#                        Bond Actor Salary
# Film
# Dr. No                               0.6
# From Russia with Love                1.6
# Goldfinger                           3.2
# Thunderball                          4.7
# Casino Royale                        NaN

# %%
bond.sort_index(inplace=True)

# %%
bond.head()
# Out:
#                       Year           Actor         Director  Box Office  \
# Film
# A View to a Kill      1985     Roger Moore        John Glen       275.2
# Casino Royale         2006    Daniel Craig  Martin Campbell       581.5
# Casino Royale         1967     David Niven       Ken Hughes       315.0
# Diamonds Are Forever  1971    Sean Connery     Guy Hamilton       442.5
# Die Another Day       2002  Pierce Brosnan     Lee Tamahori       465.4
#
#                       Budget  Bond Actor Salary
# Film
# A View to a Kill        54.5                9.1
# Casino Royale          145.3                3.3
# Casino Royale           85.0                NaN
# Diamonds Are Forever    34.7                5.8
# Die Another Day        154.2               17.9

# %%
bond['Goldfinger':'Skyfall']
# Out:
#                                  Year           Actor        Director  \
# Film
# Goldfinger                       1964    Sean Connery    Guy Hamilton
# Licence to Kill                  1989  Timothy Dalton       John Glen
# Live and Let Die                 1973     Roger Moore    Guy Hamilton
# Moonraker                        1979     Roger Moore   Lewis Gilbert
# Never Say Never Again            1983    Sean Connery  Irvin Kershner
# Octopussy                        1983     Roger Moore       John Glen
# On Her Majesty's Secret Service  1969  George Lazenby   Peter R. Hunt
# Quantum of Solace                2008    Daniel Craig    Marc Forster
# Skyfall                          2012    Daniel Craig      Sam Mendes
#
#                                  Box Office  Budget  Bond Actor Salary
# Film
# Goldfinger                            820.4    18.6                3.2
# Licence to Kill                       250.9    56.7                7.9
# ...

# %%
bond.loc[:"On Her Majesty's Secret Service"]
# Out:
#                                  Year           Actor         Director  \
# Film
# A View to a Kill                 1985     Roger Moore        John Glen
# Casino Royale                    2006    Daniel Craig  Martin Campbell
# Casino Royale                    1967     David Niven       Ken Hughes
# Diamonds Are Forever             1971    Sean Connery     Guy Hamilton
# Die Another Day                  2002  Pierce Brosnan     Lee Tamahori
# Dr. No                           1962    Sean Connery    Terence Young
# For Your Eyes Only               1981     Roger Moore        John Glen
# From Russia with Love            1963    Sean Connery    Terence Young
# GoldenEye                        1995  Pierce Brosnan  Martin Campbell
# Goldfinger                       1964    Sean Connery     Guy Hamilton
# Licence to Kill                  1989  Timothy Dalton        John Glen
# Live and Let Die                 1973     Roger Moore     Guy Hamilton
# ...

# %%
bond.loc["On Her Majesty's Secret Service":]
# Out:
# Empty DataFrame
# Columns: [Film, Year, Actor, Director, Box Office, Budget, Bond Actor Salary]
# Index: []

# %%
bond
# Out:
#                                  Year           Actor            Director  \
# Film
# A View to a Kill                 1985     Roger Moore           John Glen
# Casino Royale                    2006    Daniel Craig     Martin Campbell
# Casino Royale                    1967     David Niven          Ken Hughes
# Diamonds Are Forever             1971    Sean Connery        Guy Hamilton
# Die Another Day                  2002  Pierce Brosnan        Lee Tamahori
# Dr. No                           1962    Sean Connery       Terence Young
# For Your Eyes Only               1981     Roger Moore           John Glen
# From Russia with Love            1963    Sean Connery       Terence Young
# GoldenEye                        1995  Pierce Brosnan     Martin Campbell
# Goldfinger                       1964    Sean Connery        Guy Hamilton
# Licence to Kill                  1989  Timothy Dalton           John Glen
# Live and Let Die                 1973     Roger Moore        Guy Hamilton
# ...

# %%
pd.read_csv("jamesbond.csv",index_col=['Film'])
bond.sort_index(inplace=True)

# %%
bond.head()
# Out:
#                       Year           Actor         Director  Box Office  \
# Film
# A View to a Kill      1985     Roger Moore        John Glen       275.2
# Casino Royale         2006    Daniel Craig  Martin Campbell       581.5
# Casino Royale         1967     David Niven       Ken Hughes       315.0
# Diamonds Are Forever  1971    Sean Connery     Guy Hamilton       442.5
# Die Another Day       2002  Pierce Brosnan     Lee Tamahori       465.4
#
#                       Budget  Bond Actor Salary
# Film
# A View to a Kill        54.5                9.1
# Casino Royale          145.3                3.3
# Casino Royale           85.0                NaN
# Diamonds Are Forever    34.7                5.8
# Die Another Day        154.2               17.9

# %%
"Casino Royale"in bond.index
# Out:
# True

# %% [markdown]
# # Retrieve rows by index position

# %%
bond=pd.read_csv("jamesbond.csv",index_col=['Film'])

# %%
bond.loc['Casino Royale']
# Out:
#                Year         Actor         Director  Box Office  Budget  \
# Film
# Casino Royale  1967   David Niven       Ken Hughes       315.0    85.0
# Casino Royale  2006  Daniel Craig  Martin Campbell       581.5   145.3
#
#                Bond Actor Salary
# Film
# Casino Royale                NaN
# Casino Royale                3.3

# %%
bond.iloc[15]
# Out:
# Year                        1985
# Actor                Roger Moore
# Director               John Glen
# Box Office                 275.2
# Budget                      54.5
# Bond Actor Salary            9.1
# Name: A View to a Kill, dtype: object

# %%
bond.iloc[6:9]
# Out:
#                                  Year           Actor       Director  \
# Film
# On Her Majesty's Secret Service  1969  George Lazenby  Peter R. Hunt
# Diamonds Are Forever             1971    Sean Connery   Guy Hamilton
# Live and Let Die                 1973     Roger Moore   Guy Hamilton
#
#                                  Box Office  Budget  Bond Actor Salary
# Film
# On Her Majesty's Secret Service       291.5    37.3                0.6
# Diamonds Are Forever                  442.5    34.7                5.8
# Live and Let Die                      460.3    30.8                NaN

# %%
bond.iloc[9:6]
# Out:
# Empty DataFrame
# Columns: [Year, Actor, Director, Box Office, Budget, Bond Actor Salary]
# Index: []

# %%
bond.count()
# Out:
# Year                 26
# Actor                26
# Director             26
# Box Office           26
# Budget               26
# Bond Actor Salary    18
# dtype: int64

# %%
bond.iloc[[5,10,15,20]]
# Out:
#                          Year           Actor       Director  Box Office  \
# Film
# You Only Live Twice      1967    Sean Connery  Lewis Gilbert       514.2
# The Spy Who Loved Me     1977     Roger Moore  Lewis Gilbert       533.0
# A View to a Kill         1985     Roger Moore      John Glen       275.2
# The World Is Not Enough  1999  Pierce Brosnan  Michael Apted       439.5
#
#                          Budget  Bond Actor Salary
# Film
# You Only Live Twice        59.9                4.4
# The Spy Who Loved Me       45.1                NaN
# A View to a Kill           54.5                9.1
# The World Is Not Enough   158.3               13.5

# %% [markdown]
# # Catch all.ix() Method

# %%
bond.ix[['You Only Live Twice','Casino Royale','A View to a kill']]
# Out:
# /home/mohan/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
# /home/mohan/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   """Entry point for launching an IPython kernel.
#                        Year         Actor         Director  Box Office  \
# Film
# You Only Live Twice  1967.0  Sean Connery    Lewis Gilbert       514.2
# Casino Royale        1967.0   David Niven       Ken Hughes       315.0
# ...

# %%
bond.loc['Spectre']
# Out:
# Year                         2015
# Actor                Daniel Craig
# Director               Sam Mendes
# Box Office                  726.7
# Budget                      206.3
# Bond Actor Salary             NaN
# Name: Spectre, dtype: object

# %%
bond.index
# Out:
# Index(['Dr. No', 'From Russia with Love', 'Goldfinger', 'Thunderball',
#        'Casino Royale', 'You Only Live Twice',
#        'On Her Majesty's Secret Service', 'Diamonds Are Forever',
#        'Live and Let Die', 'The Man with the Golden Gun',
#        'The Spy Who Loved Me', 'Moonraker', 'For Your Eyes Only',
#        'Never Say Never Again', 'Octopussy', 'A View to a Kill',
#        'The Living Daylights', 'Licence to Kill', 'GoldenEye',
#        'Tomorrow Never Dies', 'The World Is Not Enough', 'Die Another Day',
#        'Casino Royale', 'Quantum of Solace', 'Skyfall', 'Spectre'],
#       dtype='object', name='Film')

# %% [markdown]
# # Second argument to .loc [], iloc[] and ix[] Method

# %%
pd.read_csv("jamesbond.csv",index_col=['Film'])
bond.sort_index(inplace=True)

# %%
bond.head()
# Out:
#                       Year           Actor         Director  Box Office  \
# Film
# A View to a Kill      1985     Roger Moore        John Glen       275.2
# Casino Royale         2006    Daniel Craig  Martin Campbell       581.5
# Casino Royale         1967     David Niven       Ken Hughes       315.0
# Diamonds Are Forever  1971    Sean Connery     Guy Hamilton       442.5
# Die Another Day       2002  Pierce Brosnan     Lee Tamahori       465.4
#
#                       Budget  Bond Actor Salary
# Film
# A View to a Kill        54.5                9.1
# Casino Royale          145.3                3.3
# Casino Royale           85.0                NaN
# Diamonds Are Forever    34.7                5.8
# Die Another Day        154.2               17.9

# %%
bond.loc['Diamonds Are Forever']
# Out:
# Year                         1971
# Actor                Sean Connery
# Director             Guy Hamilton
# Box Office                  442.5
# Budget                       34.7
# Bond Actor Salary             5.8
# Name: Diamonds Are Forever, dtype: object

# %%
bond.loc[['Diamonds Are Forever','Director']]
# Out:
# /home/mohan/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   """Entry point for launching an IPython kernel.
#                         Year         Actor      Director  Box Office  Budget  \
# Film
# Diamonds Are Forever  1971.0  Sean Connery  Guy Hamilton       442.5    34.7
# Director                 NaN           NaN           NaN         NaN     NaN
#
#                       Bond Actor Salary
# Film
# Diamonds Are Forever                5.8
# Director                            NaN

# %%
bond.loc[['Casino Royale','Director','Budget']]
# Out:
# /home/mohan/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   """Entry point for launching an IPython kernel.
#                  Year         Actor         Director  Box Office  Budget  \
# Film
# Casino Royale  2006.0  Daniel Craig  Martin Campbell       581.5   145.3
# Casino Royale  1967.0   David Niven       Ken Hughes       315.0    85.0
# Director          NaN           NaN              NaN         NaN     NaN
# Budget            NaN           NaN              NaN         NaN     NaN
#
#                Bond Actor Salary
# Film
# Casino Royale                3.3
# Casino Royale                NaN
# Director                     NaN
# Budget                       NaN

# %%
bond.reset_index(inplace=True)

# %%
bond.iloc[['Spectre'],['Budget','Year']]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-65-bf2a338d7b78> in <module>()
# ----> 1 bond.iloc[['Spectre'],['Budget','Year']]
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1470             except (KeyError, IndexError):
#    1471                 pass
# -> 1472             return self._getitem_tuple(key)
#    1473         else:
#    1474             # we by definition only have the 0th axis
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    2011     def _getitem_tuple(self, tup):
#    2012
# -> 2013         self._has_valid_tuple(tup)
#    2014         try:
#    2015             return self._getitem_lowerdim(tup)
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in _has_valid_tuple(self, key)
# ...

# %%
bond.iloc[[14],[3,2,5]]
# Out:
#     Year       Film   Director
# 14  1983  Octopussy  John Glen

# %%
bond.ix[20,'Budget']
# Out:
# /home/mohan/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
# 27.7

# %%
bond.ix['Octopussy']
# Out:
# /home/mohan/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# TypeError: an integer is required
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
# ...
