# %%
import pandas as pd
stock = pd.read_csv("google_stock_price.csv")

# %%
stock.head(3)
# Out:
#    Stock Price
# 0        50.12
# 1        54.10
# 2        54.65

# %% [markdown]
# stock.tail(3)

# %% [markdown]
# # Building Functions

# %%
len(stock)
# Out:
# 3012

# %%
type(stock)
# Out:
# pandas.core.frame.DataFrame

# %%
dir(stock)
# Out:
# ['T',
#  '_AXIS_ALIASES',
#  '_AXIS_IALIASES',
#  '_AXIS_LEN',
#  '_AXIS_NAMES',
#  '_AXIS_NUMBERS',
#  '_AXIS_ORDERS',
#  '_AXIS_REVERSED',
#  '_AXIS_SLICEMAP',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__array__',
#  '__array_wrap__',
#  '__bool__',
#  '__bytes__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__div__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
# ...

# %%
sorted(stock)
# Out:
# ['Stock Price']

# %%
list(stock)
# Out:
# ['Stock Price']

# %%
dir(stock)
# Out:
# ['T',
#  '_AXIS_ALIASES',
#  '_AXIS_IALIASES',
#  '_AXIS_LEN',
#  '_AXIS_NAMES',
#  '_AXIS_NUMBERS',
#  '_AXIS_ORDERS',
#  '_AXIS_REVERSED',
#  '_AXIS_SLICEMAP',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__array__',
#  '__array_wrap__',
#  '__bool__',
#  '__bytes__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__div__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
# ...

# %%
max(stock)
# Out:
# 'Stock Price'

# %%
min(stock)
# Out:
# 'Stock Price'

# %% [markdown]
# sum(stock)

# %%
stock.sum()
# Out:
# Stock Price    1006942.0
# dtype: float64

# %%
stock.count()
# Out:
# Stock Price    3012
# dtype: int64

# %% [markdown]
# # Mode Series Attribute

# %%
stock.values
# Out:
# array([[ 50.12],
#        [ 54.1 ],
#        [ 54.65],
#        ...,
#        [773.18],
#        [771.61],
#        [782.22]])

# %%
stock.index
# Out:
# RangeIndex(start=0, stop=3012, step=1)

# %%
stock.is_unique
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-f7cc742d02ea> in <module>()
# ----> 1 stock.is_unique
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    4370             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4371                 return self[name]
# -> 4372             return object.__getattribute__(self, name)
#    4373
#    4374     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'is_unique'

# %%
stock.ndim
# Out:
# 2

# %%
stock.shape
# Out:
# (3012, 1)

# %%
stock.size
# Out:
# 3012

# %%
stock.name
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-fa19c30d93e6> in <module>()
# ----> 1 stock.name
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    4370             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4371                 return self[name]
# -> 4372             return object.__getattribute__(self, name)
#    4373
#    4374     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'name'

# %%
stock.sort_values
# Out:
# <bound method DataFrame.sort_values of       Stock Price
# 0           50.12
# 1           54.10
# 2           54.65
# 3           52.38
# 4           52.95
# 5           53.90
# 6           53.02
# 7           50.95
# 8           51.13
# 9           50.07
# 10          50.70
# 11          49.95
# 12          50.74
# 13          51.10
# 14          51.10
# 15          52.61
# 16          53.70
# 17          55.69
# 18          55.94
# 19          56.93
# 20          58.69
# 21          59.62
# 22          58.86
# 23          59.13
# 24          60.35
# 25          59.86
# 26          59.07
# 27          63.37
# 28          65.47
# 29          64.74
# ...           ...
# 2982       675.22
# 2983       668.26
# 2984       680.04
# 2985       684.11
# 2986       692.10
# 2987       699.21
# 2988       694.49
# 2989       697.77
# 2990       695.36
# 2991       705.63
# 2992       715.09
# 2993       720.64
# 2994       716.98
# 2995       720.95
# 2996       719.85
# 2997       733.78
# ...

# %%
stock.sort_values('Stock Price', ascending=False).head(10)
# Out:
#       Stock Price
# 3011       782.22
# 2859       776.60
# 3009       773.18
# 3007       772.88
# 3010       771.61
# 3008       771.07
# 2860       771.00
# 3006       768.79
# 2840       767.04
# 2843       766.81

# %%
import pandas as series

# %%
stock.sort_values('Stock Price', ascending=False, inplace = False)
# Out:
#       Stock Price
# 3011       782.22
# 2859       776.60
# 3009       773.18
# 3007       772.88
# 3010       771.61
# 3008       771.07
# 2860       771.00
# 3006       768.79
# 2840       767.04
# 2843       766.81
# 2934       766.61
# 2882       764.65
# 2844       763.25
# 2858       762.51
# 2841       762.38
# 2845       762.37
# 2937       759.14
# 2933       759.00
# 2861       758.88
# 2851       758.09
# 2834       756.60
# 2835       755.98
# 2935       753.93
# 2932       753.20
# 2936       752.67
# 2842       752.54
# 2881       752.00
# 2931       751.72
# 2846       751.61
# 2921       750.53
# ...           ...
# 28          65.47
# 29          64.74
# 27          63.37
# 24          60.35
# 25          59.86
# 21          59.62
# 23          59.13
# 26          59.07
# 22          58.86
# 20          58.69
# 19          56.93
# 18          55.94
# 17          55.69
# 2           54.65
# 1           54.10
# 5           53.90
# 16          53.70
# 6           53.02
# ...

# %%
stock.sort_index(ascending = True)
# Out:
#       Stock Price
# 0           50.12
# 1           54.10
# 2           54.65
# 3           52.38
# 4           52.95
# 5           53.90
# 6           53.02
# 7           50.95
# 8           51.13
# 9           50.07
# 10          50.70
# 11          49.95
# 12          50.74
# 13          51.10
# 14          51.10
# 15          52.61
# 16          53.70
# 17          55.69
# 18          55.94
# 19          56.93
# 20          58.69
# 21          59.62
# 22          58.86
# 23          59.13
# 24          60.35
# 25          59.86
# 26          59.07
# 27          63.37
# 28          65.47
# 29          64.74
# ...           ...
# 2982       675.22
# 2983       668.26
# 2984       680.04
# 2985       684.11
# 2986       692.10
# 2987       699.21
# 2988       694.49
# 2989       697.77
# 2990       695.36
# 2991       705.63
# 2992       715.09
# 2993       720.64
# 2994       716.98
# 2995       720.95
# 2996       719.85
# 2997       733.78
# 2998       736.96
# 2999       741.19
# ...
